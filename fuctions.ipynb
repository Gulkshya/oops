# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulkshya/oops/blob/main/fuctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.  What is the difference between a function and a method in Python?
#
# >>In Python, a function is a block of code that performs a task, while a method is a function that is associated with an object or class.
#
# >>Differences:
#
# >>1.Scope:
#
# >>Functions are independent blocks of code, while methods are tied to objects or classes.
#
# >>2.Invocation:
#
# >>Functions are called by name, while methods are accessed using dot notation.
#
# >>3.Reusability:
# >>Functions can be reused, while methods offer behavior specific to objects.
#
# >>4.Object-oriented programming:
#
# >>Methods are applicable only for object-oriented programming languages, while functions can be used for both object-oriented and non-object-oriented programming languages.
#
# >>5.Arguments:
#
# >>Functions may have zero or many arguments, while the first argument of a method should be 'self'.
#
# >>Examples:
#
# >>Function: A function that calculates the factorial of a number.
#
# >>Method: A method that initializes a car with a make and model.

# %% [markdown]
# # 2. Explain the concept of function arguments and parameters in Python.
#
# >>Parameters are variables defined in a function declaration. This act as placeholders for the values (arguments) that will be passed to the function.
#
#
# >>Arguments are the actual values that you pass to the function when you call it. These values replace the parameters defined in the function.
#
# >>example:
#
# >>def
#
# >>sum(a,b):    #a,b are parameters
#
#   >>print(a+b)
#
#   >>sum(1,2)      #the values 1,2 are arguments
#
#   >>output:3
#
#
#   # 3. What are the different ways to define and call a function in Python?
#
# >>To define and call a function in Python, you can use the def keyword to declare the function, and then use the function name followed by parentheses to call it.
#
# >>Defining a function:
# * Use the def keyword
# * Follow with the function name
# * Add parameters within parentheses
# * End the line with a colon
# * Add statements to execute
# * End with a return statement if the function should output something
#
#
#
#
# >>Calling a function:
# * Use the function name
# *Follow with parentheses
#
# >>Examples
# * Defining a function: def my_function(): print("Hello from a function")
# * Calling a function: my_function()
#
# # 4. What is the purpose of the `return` statement in a Python function?
#
#  >>The return statement in Python sends the result of a function back to the caller. It can be used to:
#
# * Return the result of a calculation
# * Retrieve data from a database or API
# * Exit a function based on conditions
# * Use the result in other parts of the code
# * Examples:
# * Returning a string:
# * def str_value(s): return str(s)
#
# # 5. What are iterators in Python and how do they differ from iterables?
#
# >>An iterable is a object which has a __iter__() method. It can possibly iterated over several times, such as list() s and tuple() s.
#
# >> An iterator is the object which iterates. It is returned by an __iter__() method, returns itself via its own __iter__() method and has a next() method ( __next__() in 3.
#
# # 6. Explain the concept of generators in Python and how they are defined.
#
# >>A generator function is a special type of function that returns an iterator object. Instead of using return to send back a single value, generator functions use yield to produce a series of results over time. This allows the function to generate values and pause its execution after each yield, maintaining its state between iterations.
#
#
# >>Basic Code Example:
# * def fun(max):
#  * cnt = 1
#
#  # 7. What are the advantages of using generators over regular functions?
#
#  >>Generators have several advantages over regular functions, including:
# Memory efficiency: Generators produce values one at a time, so they don't need to store the entire sequence in memory. This makes them ideal for large datasets.
#
# >>Improved performance: Generators only compute values when needed, which can improve performance for applications that don't require the entire sequence at once.
#
# >>Lazy evaluation: Generators process elements only when needed, which is called lazy evaluation.
#
# >>Infinite sequences: Generators can produce an infinite sequence of values, as long as there is enough memory to store them.
#
# >>Readability: Generators can make code more readable and concise.
# Iterators: Generators can be used to create iterators for custom data structures.
#
#
# # 8. What is a lambda function in Python and when is it typically used?
#
# >>In Python, a lambda function is a small, anonymous function that is used to evaluate a single expression and return the result.
# * Lambda functions are typically used for short-term functions or one-off operations.
# * They are defined using the lambda keyword and are similar to regular functions, which are defined using the def keyword.
#
# >> Here are some examples of when to use lambda functions:
# * Sorting:
# Lambda functions can be used to sort Python data structures, such as lists and dictionaries.
# * Filtering:
# Lambda functions can be used with the filter() function to check if a number in a list is even or not.
# * Creating new columns:
# Lambda functions can be used with the assign() function to create new columns or modify existing ones in a DataFrame.
#
# # 9. Explain the purpose and usage of the `map()` function in Python?
#
# >>The map() function in Python applies a function to each element of an iterable, such as a list or tuple. It returns an iterator that yields transformed items.
# * Purpose :
# * Processes and transforms iterables without using a for loop.
# * Applies a function to each item in an iterable.
# * Returns a list of results.
#
# >>Usage:
# * Transforming iterables of strings: Convert a list of strings into a list of integers.
# * Processing multiple input iterables: Accept multiple inputs in a single line
# Using built-in functions: Use built-in functions like list(), set(), and tuple() .
# * Using lambda functions: Use a lambda expression to create an anonymous function in a single line of code.
#
# >>Examples:
# * Squaring numbers: Apply the square() function to each item in the numbers list
# * Converting Celsius to Fahrenheit: Apply a lambda function to a list of temperatures in Celsius to convert them to Fahrenheit
# * Adding an underscore to the end of each value in a dictionary: Apply a lambda function to the items in a dictionary .
#
# # 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# >>The main differences between the map(), filter(), and reduce() functions in Python are what they do and how they return their results:
# * map():
# Applies a function to each element in an iterable, like a list or set, and returns a list of the results. For example, you can use map() to cast integers into strings.
#
# * filter()
# Creates a list from elements of an iterable for which a function returns true. For example, you can use filter() to filter out countries with names that don't contain a certain string.
#
# * reduce()
# Applies a rolling computation to sequential pairs of values in a list and returns a single result. For example, you can use reduce() to multiply two numbers in consecutive fashion.
#
# # 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# **bold text**![Question 11.pdf](data:application/pdf;base64,...)

# %% [markdown]
# # **Practical Question**
# **1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.**

# %%
def sum_of_even_numbers(numbers):
    """
    Calculate the sum of all even numbers in a list.

    Args:
        numbers (list): A list of integers.

    Returns:
        int: The sum of all even numbers in the list.
    """
    return sum(num for num in numbers if num % 2 == 0)

# Example usage
numbers_list = [1, 2, 3, 4, 5, 6]
print(f"Sum of even numbers: {sum_of_even_numbers(numbers_list)}")
# Out:
# Sum of even numbers: 12

# %% [markdown]
# **2. Create a Python function that accepts a string and returns the reverse of that string.**

# %%
def reverse_string(s):
    """
    Reverse a given string.

    Args:
        s (str): The string to reverse.

    Returns:
        str: The reversed string.
    """
    return s[::-1]

# Example usage
input_string = "hello"
print(f"Reversed string: {reverse_string(input_string)}")

# %% [markdown]
# **3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.**

# %%
def square_numbers(numbers):
    """
    Calculate the squares of each number in a list.

    Args:
        numbers (list): A list of integers.

    Returns:
        list: A new list containing the squares of the input numbers.
    """
    return [num ** 2 for num in numbers]

# Example usage
numbers_list = [1, 2, 3, 4, 5]
print(f"Squares of numbers: {square_numbers(numbers_list)}")

# %% [markdown]
# **4. Write a Python function that checks if a given number is prime or not from 1 to 200.**

# %%
def is_prime(n):
    """
    Check if a number is prime.

    Args:
        n (int): The number to check.

    Returns:
        bool: True if the number is prime, False otherwise.
    """
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# Test the function for numbers from 1 to 200
for num in range(1, 201):
    print(f"{num} is prime: {is_prime(num)}")

# %% [markdown]
# ** 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.**

# %%
class FibonacciIterator:
    """
    An iterator class to generate the Fibonacci sequence up to a specified number of terms.
    """
    def __init__(self, n_terms):
        """
        Initialize the iterator with the number of terms.

        Args:
            n_terms (int): The number of Fibonacci terms to generate.
        """
        self.n_terms = n_terms
        self.current = 0
        self.next = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return self.current
        elif self.count == 1:
            self.count += 1
            return self.next
        else:
            fib = self.current + self.next
            self.current, self.next = self.next, fib
            self.count += 1
            return fib

# Example usage
n = 10  # Number of Fibonacci terms
fib_iterator = FibonacciIterator(n)
print(f"First {n} Fibonacci numbers:")
for fib in fib_iterator:
    print(fib)

# %% [markdown]
# **6. Write a generator function in Python that yields the powers of 2 up to a given exponent.**

# %%
def powers_of_two(max_exponent):
    """
    Generate powers of 2 up to a given exponent.

    Args:
        max_exponent (int): The maximum exponent to generate powers of 2 for.

    Yields:
        int: The powers of 2 from 2^0 to 2^max_exponent.
    """
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent

# Example usage
max_exp = 10
print(f"Powers of 2 up to 2^{max_exp}:")
for power in powers_of_two(max_exp):
    print(power)

# %% [markdown]
# **7. Implement a generator function that reads a file line by line and yields each line as a string.**

# %%
def read_file_line_by_line(file_path):
    """
    Generator function to read a file line by line.

    Args:
        file_path (str): The path to the file.

    Yields:
        str: Each line in the file as a string.
    """
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.rstrip('\n')  # Remove the newline character at the end of each line
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Example usage
file_name = "example.txt"  # Replace with the path to your file
for line in read_file_line_by_line(file_name):
    print(line)

# %% [markdown]
# **8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple**

# %%
# List of tuples
tuples_list = [(1, 3), (4, 1), (2, 5), (3, 2)]

# Sorting the list using a lambda function
sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Output the sorted list
print("Sorted list based on the second element:", sorted_list)

# %% [markdown]
# **9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.**

# %%
def celsius_to_fahrenheit(celsius):
    """
    Convert Celsius to Fahrenheit.

    Args:
        celsius (float): Temperature in Celsius.

    Returns:
        float: Temperature in Fahrenheit.
    """
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 20, 37, 100]

# Convert to Fahrenheit using map()
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Output the result
print("Temperatures in Celsius:", celsius_temperatures)
print("Temperatures in Fahrenheit:", fahrenheit_temperatures)

# %% [markdown]
# **10. Create a Python program that uses `filter()` to remove all the vowels from a given string.**

# %%
def celsius_to_fahrenheit(celsius):
    """
    Convert Celsius to Fahrenheit.

    Args:
        celsius (float): Temperature in Celsius.

    Returns:
        float: Temperature in Fahrenheit.
    """
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 20, 37, 100]

# Convert to Fahrenheit using map()
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Output the result
print("Temperatures in Celsius:", celsius_temperatures)
print("Temperatures in Fahrenheit:", fahrenheit_temperatures)

# %% [markdown]
# **11 Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# * order number____book title and author___Quantity___Price per item
#
#
# 1.   34587-->>learning python by lutz__________4__________40.95
# 2.   98762-->>programming python mark lutz__5__________56.80
# 3.   77226-->>head first python,paul berry______3__________32.95
# 4.  88112-->>python3, berned klein____________3__________24.99
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.**

# %%
# List of orders
orders = [
    (34587, "Learning Python by Mark Lutz", 4, 40.95),
    (98762, "Programming Python by Mark Lutz", 5, 56.80),
    (77226, "Head First Python by Paul Barry", 3, 32.95),
    (88112, "Python 3 by Bernd Klein", 3, 24.99),
]

# Using lambda and map to calculate the total price for each order
result = list(map(
    lambda order: (
        order[0],  # Order number
        round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)  # Total price with adjustment
    ),
    orders
))

# Output the result
print("Processed Orders:")
for order in result:
    print(order)
